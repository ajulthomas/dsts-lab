# %% [markdown]
# ## Problem Statement:
# Here, you need to edit this text to descibe the problem that need to be solved.
# Also, you need to determine which machine learning this problem belong to.

# %% [markdown]
# ## Objectives
# Define the objectives/goals that you are targeting in this task

# %% [markdown]
# ## Working Code

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# add other libraries as you go
# code goes here

import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# load data
data_path = "data/weatherAUS.csv"
weather_data = pd.read_csv(data_path)

# check the data dimension and print first few rows
print(f"data has {weather_data.shape[0]} rows and {weather_data.shape[1]} columns")

df_rows = weather_data.shape[0]
df_cols = weather_data.shape[1]
# Out:
# data has 198656 rows and 24 columns

# %%
# check the dataset
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198656 entries, 0 to 198655
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           198656 non-null  object
#  1   Location       198656 non-null  object
#  2   MinTemp        195647 non-null  float64
#  3   MaxTemp        195849 non-null  float64
#  4   Rainfall       193292 non-null  float64
#  5   Evaporation    96716 non-null   float64
#  6   Sunshine       88211 non-null   float64
#  7   WindGustDir    183548 non-null  object
#  8   WindGustSpeed  183657 non-null  float64
#  9   WindDir9am     183069 non-null  object
#  10  WindDir3pm     190469 non-null  object
#  11  WindSpeed9am   195074 non-null  float64
#  12  WindSpeed3pm   191852 non-null  float64
#  13  Humidity9am    194602 non-null  float64
#  14  Humidity3pm    190792 non-null  float64
#  15  Pressure9am    176742 non-null  float64
#  16  Pressure3pm    176752 non-null  float64
#  17  Cloud9am       114702 non-null  float64
#  18  Cloud3pm       108659 non-null  float64
#  19  Temp9am        195604 non-null  float64
#  20  Temp3pm        191800 non-null  float64
#  21  RainToday      193292 non-null  object
#  22  RISK_MM        193292 non-null  float64
#  23  RainTomorrow   193292 non-null  object
# dtypes: float64(17), object(7)
# memory usage: 36.4+ MB

# %%
# split date column into day month year
weather_data['Date'] = pd.to_datetime(weather_data['Date'])
weather_data['Year'] = weather_data['Date'].dt.year
weather_data['Month'] = weather_data['Date'].dt.month
weather_data['Day'] = weather_data['Date'].dt.day

# drop the original date column
weather_data.drop('Date', axis=1, inplace=True)

# %% [markdown]
# ### Categorical or Continous?
# Define which variables are categorical and which are not

# %%
# code goes here
columns_types = weather_data.dtypes

category_columns = []
numerical_columns = []

for column_name, column_type in columns_types.items():
    if column_type == 'object':
        category_columns.append(column_name)
    else:
        numerical_columns.append(column_name)
print(f"numerical columns: {numerical_columns}")
print(f"categorical columns: {category_columns}")
# Out:
# numerical columns: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RISK_MM', 'Year', 'Month', 'Day']
# categorical columns: ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %% [markdown]
# ### Explore the categorical variables
# You need to judge on the selected techniques of the EDA (i.e., why have you used this techniques?)

# %%
# code goes here

df_cat_features = weather_data[category_columns]

df_cat_features.head()
# Out:
#   Location WindGustDir WindDir9am WindDir3pm RainToday RainTomorrow
# 0   Albury           W          W        WNW        No           No
# 1   Albury         WNW        NNW        WSW        No           No
# 2   Albury         WSW          W        WSW        No           No
# 3   Albury          NE         SE          E        No           No
# 4   Albury           W        ENE         NW        No           No

# %%
# count plot for each categorical variable

# plot the count plot for location
plt.figure(figsize=(20, 10))
sns.countplot(y='Location', data=weather_data, stat='count')
# Out:
# <Axes: xlabel='count', ylabel='Location'>

# %% [markdown]
# ### Explore the contiunous variables
# You need to judge on the selected techniques of the EDA (i.e., why have you used this techniques?)

# %%
# code goes here

# %% [markdown]
# ### Split data into separate training (70%) and test set (30%)

# %%
# code goes here

# %% [markdown]
# ### Feature engineering (i.e., handling missings and outliers)

# %%
# code goes here

# %% [markdown]
# ### Data modelling
# Please select at least three techniques as your selected data modelling. Please explain your choices

# %%
# code goes here

# %% [markdown]
# ### Prediction
# Generate the predicted output for each of the built models

# %%
# code goes here

# %% [markdown]
# ### Evaluation on testing data
# Please evaluate the three created models on the testing data and explain the selected evaluation metrics

# %%
# code goes here

# %% [markdown]
# ## Insights and report results
# Please draw your insights here and the most interesting finidng and reflect on the achieved goals
